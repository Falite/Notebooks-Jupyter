# %% [markdown]
# # Ouverture et découverte du Dataset

# %%
import pandas as pd
import seaborn as sns

# %%
df_smartmob=pd.read_csv('smart_mobility_dataset.csv')
df_smartmob.head()
# Out:
#              Timestamp   Latitude  Longitude  Vehicle_Count  \
# 0  2024-03-01 00:00:00  40.842275 -73.703149            205
# 1  2024-03-01 00:05:00  40.831119 -73.987354            202
# 2  2024-03-01 00:10:00  40.819549 -73.732462            252
# 3  2024-03-01 00:15:00  40.725849 -73.980134             37
# 4  2024-03-01 00:20:00  40.813265 -73.961631             64
#
#    Traffic_Speed_kmh  Road_Occupancy_% Traffic_Light_State Weather_Condition  \
# 0          49.893435         82.652780              Yellow             Clear
# 1          22.383965         45.829298               Green             Clear
# 2          46.889699         82.772465               Green              Rain
# 3           5.730536         37.695567                 Red               Fog
# 4          61.348034         22.313358                 Red              Snow
#
#    Accident_Report  Sentiment_Score  Ride_Sharing_Demand  \
# 0                0        -0.609199                    2
# ...

# %%
df_smartmob.shape
# Out:
# (5000, 15)

# %%
df_smartmob.describe()
# Out:
#           Latitude    Longitude  Vehicle_Count  Traffic_Speed_kmh  \
# count  5000.000000  5000.000000    5000.000000        5000.000000
# mean     40.749645   -73.847433     153.921200          42.111096
# std       0.086123     0.086204      83.523342          21.707720
# min      40.600016   -73.999987      10.000000           5.002789
# 25%      40.675403   -73.920281      80.000000          23.195752
# 50%      40.748875   -73.846058     156.000000          42.191599
# 75%      40.824735   -73.771685     226.000000          60.751760
# max      40.899972   -73.700159     299.000000          79.997556
#
#        Road_Occupancy_%  Accident_Report  Sentiment_Score  \
# count       5000.000000      5000.000000      5000.000000
# mean          54.748397         0.096000        -0.005652
# std           26.145238         0.294621         0.583790
# min           10.005031         0.000000        -0.999819
# 25%           32.089653         0.000000        -0.500154
# ...

# %%
df_smartmob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               5000 non-null   object
#  1   Latitude                5000 non-null   float64
#  2   Longitude               5000 non-null   float64
#  3   Vehicle_Count           5000 non-null   int64
#  4   Traffic_Speed_kmh       5000 non-null   float64
#  5   Road_Occupancy_%        5000 non-null   float64
#  6   Traffic_Light_State     5000 non-null   object
#  7   Weather_Condition       5000 non-null   object
#  8   Accident_Report         5000 non-null   int64
#  9   Sentiment_Score         5000 non-null   float64
#  10  Ride_Sharing_Demand     5000 non-null   int64
#  11  Parking_Availability    5000 non-null   int64
#  12  Emission_Levels_g_km    5000 non-null   float64
#  13  Energy_Consumption_L_h  5000 non-null   float64
# ...

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df_smartmob)
# Out:
# <Axes: >

# %% [markdown]
# # Visualisation et Correction des données si besoin

# %%
df_smartmob.isna().sum()
# Out:
# Timestamp                 0
# Latitude                  0
# Longitude                 0
# Vehicle_Count             0
# Traffic_Speed_kmh         0
# Road_Occupancy_%          0
# Traffic_Light_State       0
# Weather_Condition         0
# Accident_Report           0
# Sentiment_Score           0
# Ride_Sharing_Demand       0
# Parking_Availability      0
# Emission_Levels_g_km      0
# Energy_Consumption_L_h    0
# Traffic_Condition         0
# dtype: int64

# %%
df_smartmob.isnull().sum()
# Out:
# Timestamp                 0
# Latitude                  0
# Longitude                 0
# Vehicle_Count             0
# Traffic_Speed_kmh         0
# Road_Occupancy_%          0
# Traffic_Light_State       0
# Weather_Condition         0
# Accident_Report           0
# Sentiment_Score           0
# Ride_Sharing_Demand       0
# Parking_Availability      0
# Emission_Levels_g_km      0
# Energy_Consumption_L_h    0
# Traffic_Condition         0
# dtype: int64

# %% [markdown]
# ## Concernant le Timestamp

# %%
df_smartmob['Timestamp'].value_counts()
# Out:
# Timestamp
# 2024-03-01 00:00:00    1
# 2024-03-12 13:30:00    1
# 2024-03-12 14:05:00    1
# 2024-03-12 14:00:00    1
# 2024-03-12 13:55:00    1
#                       ..
# 2024-03-06 18:50:00    1
# 2024-03-06 18:45:00    1
# 2024-03-06 18:40:00    1
# 2024-03-06 18:35:00    1
# 2024-03-18 08:35:00    1
# Name: count, Length: 5000, dtype: int64

# %% [markdown]
# elles sont toutes différentes

# %% [markdown]
# ## Concernant les conditions météo

# %%
df_smartmob['Weather_Condition'].value_counts()
# Out:
# Weather_Condition
# Rain     1279
# Snow     1257
# Fog      1245
# Clear    1219
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df_smartmob['Weather_Condition'], bins=25)
plt.show()

# %%
colors = ['#10E1C8', '#7FB3BC', '#9BB0B4', '#DBE2E3']
sns.barplot(x=df_smartmob['Weather_Condition'], y=df_smartmob['Weather_Condition'].index,
           palette=colors)
# Out:
# /var/folders/kd/pckgp4pd2mz19vk2ljkn8xf00000gp/T/ipykernel_52052/1045988236.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_smartmob['Weather_Condition'], y=df_smartmob['Weather_Condition'].index,
# <Axes: xlabel='Weather_Condition', ylabel='None'>

# %% [markdown]
# elles sont uniformément réparties.

# %% [markdown]
# ## Concernant le Traffic Light State

# %%
df_smartmob['Traffic_Light_State'].value_counts()
# Out:
# Traffic_Light_State
# Yellow    1726
# Green     1651
# Red       1623
# Name: count, dtype: int64

# %%
plt.hist(df_smartmob['Traffic_Light_State'], bins=25)
plt.show()

# %%
colors=['#F4D03F','#2ecc71','#c0392b']
sns.barplot(x=df_smartmob['Traffic_Light_State'],y=df_smartmob['Traffic_Light_State'].index,
            palette=colors)
# Out:
# /var/folders/kd/pckgp4pd2mz19vk2ljkn8xf00000gp/T/ipykernel_52052/24700963.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_smartmob['Traffic_Light_State'],y=df_smartmob['Traffic_Light_State'].index,
# <Axes: xlabel='Traffic_Light_State', ylabel='None'>

# %% [markdown]
# idem que précédemment.

# %% [markdown]
# ## Autres données

# %%
plt.figure(figsize=(3,2))
plt.plot(df_smartmob['Latitude'])
plt.title('graphique de la lattitude')
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.plot(df_smartmob['Longitude'])
plt.title('graphique de la Longitude')
plt.show()

# %%
sns.scatterplot(x=df_smartmob['Latitude'], y=df_smartmob['Longitude'])
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>

# %%
sns.scatterplot(x=df_smartmob['Latitude'], y=df_smartmob['Longitude'],
               hue=df_smartmob['Traffic_Light_State'])
# Out:
# <Axes: xlabel='Latitude', ylabel='Longitude'>

# %%
plt.plot(df_smartmob['Vehicle_Count'])
plt.title('graphique du nombre de véhicules')
plt.show()

# %%
sns.pairplot(df_smartmob.select_dtypes(include='number'))
plt.show()

# %% [markdown]
# ## Sur les accidents

# %%
count_accidents=df_smartmob['Accident_Report'].value_counts()
count_accidents.plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(x=df_smartmob['Traffic_Speed_kmh'], y=df_smartmob['Road_Occupancy_%'],
                hue=df_smartmob['Accident_Report'])
# Out:
# <Axes: xlabel='Traffic_Speed_kmh', ylabel='Road_Occupancy_%'>

# %%
sns.swarmplot(x=df_smartmob['Accident_Report'], y=df_smartmob['Sentiment_Score'])
# Out:
# /Users/abdoullatif.opro/Library/Python/3.12/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 42.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Accident_Report', ylabel='Sentiment_Score'>
# /Users/abdoullatif.opro/Library/Python/3.12/lib/python/site-packages/seaborn/categorical.py:3399: UserWarning: 68.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(y='Traffic_Speed_kmh', x='Vehicle_Count', hue='Accident_Report', data=df_smartmob)

# %%
df_smartmob.head()
# Out:
#              Timestamp   Latitude  Longitude  Vehicle_Count  \
# 0  2024-03-01 00:00:00  40.842275 -73.703149            205
# 1  2024-03-01 00:05:00  40.831119 -73.987354            202
# 2  2024-03-01 00:10:00  40.819549 -73.732462            252
# 3  2024-03-01 00:15:00  40.725849 -73.980134             37
# 4  2024-03-01 00:20:00  40.813265 -73.961631             64
#
#    Traffic_Speed_kmh  Road_Occupancy_% Traffic_Light_State Weather_Condition  \
# 0          49.893435         82.652780              Yellow             Clear
# 1          22.383965         45.829298               Green             Clear
# 2          46.889699         82.772465               Green              Rain
# 3           5.730536         37.695567                 Red               Fog
# 4          61.348034         22.313358                 Red              Snow
#
#    Accident_Report  Sentiment_Score  Ride_Sharing_Demand  \
# 0                0        -0.609199                    2
# ...

# %% [markdown]
# # Recherche de corrélation entre variables

# %%
list_corr=['Vehicle_Count','Traffic_Speed_kmh','Road_Occupancy_%','Accident_Report','Sentiment_Score',
           'Ride_Sharing_Demand','Parking_Availability','Emission_Levels_g_km','Energy_Consumption_L_h'
          ]
df_smartmob_corr = df_smartmob[list_corr]
matrice_smartmob=df_smartmob_corr.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(matrice_smartmob, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# # Modèles d'entraînement

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2025-03-23 12:06:41.018696: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Préparation des données

# %%
variables_intérêt=['Vehicle_Count', 'Traffic_Speed_kmh', 'Road_Occupancy_%', 'Sentiment_Score', 'Ride_Sharing_Demand', 'Parking_Availability', 
                   'Emission_Levels_g_km', 'Energy_Consumption_L_h']
X=df_smartmob[variables_intérêt]
Y=df_smartmob['Accident_Report']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((4000, 8), (1000, 8), (4000,), (1000,))

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ## Écriture du modèle

# %%
model_seq = Sequential()
model_seq.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model_seq.add(Dense(32, activation='relu'))
model_seq.add(Dense(1, activation='sigmoid'))
# Out:
# /Users/abdoullatif.opro/Library/Python/3.12/lib/python/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_seq.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model_seq.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Entraînement et évaluation du modèle

# %%
historique=model_seq.fit(X_train, Y_train, epochs=20, batch_size=64, validation_split=0.2)

test_perte, test_précision = model_seq.evaluate(X_test, Y_test, verbose=0)
print(f'Test de précision: {test_précision*100:.2f}%')
# Out:
# Epoch 1/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.7712 - loss: 0.5408 - val_accuracy: 0.9175 - val_loss: 0.2997
# Epoch 2/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8942 - loss: 0.3446 - val_accuracy: 0.9175 - val_loss: 0.2921
# Epoch 3/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8962 - loss: 0.3373 - val_accuracy: 0.9175 - val_loss: 0.2929
# Epoch 4/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8985 - loss: 0.3281 - val_accuracy: 0.9175 - val_loss: 0.2929
# Epoch 5/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8996 - loss: 0.3279 - val_accuracy: 0.9175 - val_loss: 0.2944
# Epoch 6/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9003 - loss: 0.3223 - val_accuracy: 0.9175 - val_loss: 0.2943
# Epoch 7/20
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8879 - loss: 0.3470 - val_accuracy: 0.9175 - val_loss: 0.2947
# Epoch 8/20
# ...

# %%
print(f'Perte: {test_perte}')
print(f'Précision: {test_précision}')
# Out:
# Perte: 0.3067745864391327
# Précision: 0.9120000004768372

# %%
plt.plot(historique.history['accuracy'])
plt.plot(historique.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Époque')
plt.legend(['Entraînement', 'Validation'], loc='upper left')
plt.show()

# %%
X_predict=model_seq.predict(X_train)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
df_smartmob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               5000 non-null   object
#  1   Latitude                5000 non-null   float64
#  2   Longitude               5000 non-null   float64
#  3   Vehicle_Count           5000 non-null   int64
#  4   Traffic_Speed_kmh       5000 non-null   float64
#  5   Road_Occupancy_%        5000 non-null   float64
#  6   Traffic_Light_State     5000 non-null   object
#  7   Weather_Condition       5000 non-null   object
#  8   Accident_Report         5000 non-null   int64
#  9   Sentiment_Score         5000 non-null   float64
#  10  Ride_Sharing_Demand     5000 non-null   int64
#  11  Parking_Availability    5000 non-null   int64
#  12  Emission_Levels_g_km    5000 non-null   float64
#  13  Energy_Consumption_L_h  5000 non-null   float64
# ...
