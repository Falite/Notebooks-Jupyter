# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Lecture et découverte du dataframe Bitcoin

# %%
df_Bitcoin = pd.read_csv("btcusd_1-min_data.csv")
df_Bitcoin.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume                   datetime
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:01:00+00:00
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:02:00+00:00
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:03:00+00:00
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:04:00+00:00
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:05:00+00:00

# %%
df_Bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6944800 entries, 0 to 6944799
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
#  6   datetime   object
# dtypes: float64(6), object(1)
# memory usage: 370.9+ MB

# %%
print(df_Bitcoin.shape)
# Out:
# (6944800, 7)

# %%
df_Bitcoin.isna().sum()
# Out:
# Timestamp         0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# datetime     162520
# dtype: int64

# %%
df_Bitcoin.isnull().sum()
# Out:
# Timestamp         0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# datetime     162520
# dtype: int64

# %% [markdown]
# ## Observation de variables en détail

# %%
df_Bitcoin["Timestamp"].value_counts()
# Out:
# Timestamp
# 1.325412e+09    1
# 1.603203e+09    1
# 1.603204e+09    1
# 1.603204e+09    1
# 1.603204e+09    1
#                ..
# 1.464308e+09    1
# 1.464308e+09    1
# 1.464308e+09    1
# 1.464308e+09    1
# 1.742170e+09    1
# Name: count, Length: 6944800, dtype: int64

# %%
df_Bitcoin["Open"].value_counts()
# Out:
# Open
# 5.00        7985
# 5.07        7003
# 276.80      6571
# 5.08        6134
# 4.91        5958
#             ...
# 48968.73       1
# 48981.87       1
# 49031.57       1
# 48976.77       1
# 13137.76       1
# Name: count, Length: 1726816, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_Bitcoin['Open'], bins=50, kde=True)
plt.title('Distribution de la variable Open')
plt.xlabel('Valeur')
plt.ylabel('Fréquence')
plt.show()

# %%
df_Bitcoin["High"].value_counts()
# Out:
# High
# 5.00        7988
# 5.07        6997
# 276.80      6576
# 5.08        6134
# 4.91        5956
#             ...
# 19415.95       1
# 19431.47       1
# 19422.06       1
# 19415.73       1
# 82135.00       1
# Name: count, Length: 1691396, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_Bitcoin['High'], bins=50, kde=True)
plt.title('Distribution de la variable High')
plt.xlabel('Valeur')
plt.ylabel('Fréquence')
plt.show()

# %%
df_Bitcoin["Low"].value_counts()
# Out:
# Low
# 5.00        7989
# 5.07        7003
# 276.80      6576
# 5.08        6133
# 4.91        5958
#             ...
# 18471.78       1
# 18473.57       1
# 18463.76       1
# 18445.60       1
# 82389.00       1
# Name: count, Length: 1702777, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_Bitcoin['Low'], bins=50, kde=True)
plt.title('Distribution de la variable High')
plt.xlabel('Valeur')
plt.ylabel('Fréquence')
plt.show()

# %%
df_Bitcoin["Close"].value_counts()
# Out:
# Close
# 5.00        7990
# 5.07        6997
# 276.80      6578
# 5.08        6133
# 4.91        5955
#             ...
# 50778.61       1
# 50816.69       1
# 50782.61       1
# 50695.87       1
# 13303.37       1
# Name: count, Length: 1718599, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_Bitcoin['Close'], bins=50, kde=True)
plt.title('Distribution de la variable Close')
plt.xlabel('Valeur')
plt.ylabel('Fréquence')
plt.show()

# %%
df_Bitcoin["Volume"].value_counts()
# Out:
# Volume
# 0.000000     1307905
# 1.000000       26779
# 0.500000       11813
# 0.100000       10954
# 2.000000       10479
#               ...
# 26.471895          1
# 32.813506          1
# 91.050282          1
# 68.940308          1
# 0.003019           1
# Name: count, Length: 4880357, dtype: int64

# %%
df_Bitcoin["datetime"].value_counts()
# Out:
# datetime
# 2012-01-01 10:01:00+00:00    1
# 2020-08-06 16:38:00+00:00    1
# 2020-08-06 16:48:00+00:00    1
# 2020-08-06 16:47:00+00:00    1
# 2020-08-06 16:46:00+00:00    1
#                             ..
# 2016-04-19 13:17:00+00:00    1
# 2016-04-19 13:16:00+00:00    1
# 2016-04-19 13:15:00+00:00    1
# 2016-04-19 13:14:00+00:00    1
# 2025-03-15 00:00:00+00:00    1
# Name: count, Length: 6782280, dtype: int64

# %% [markdown]
# ## Etude de la corrélation entre certaines variables

# %%
df_Bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6944800 entries, 0 to 6944799
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
#  6   datetime   object
# dtypes: float64(6), object(1)
# memory usage: 370.9+ MB

# %%
list_corr=['Open','High','Low','Close','Volume']

df_Bitcoin_corr=df_Bitcoin[list_corr]

matrice_Bitcoin_corr=df_Bitcoin_corr.corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(matrice_Bitcoin_corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
