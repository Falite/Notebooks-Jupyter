# %% [markdown]
# # Vaccinations par pays

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_vaccin = pd.read_csv('country_vaccinations.csv')
df_vaccin_man = pd.read_csv('country_vaccinations_by_manufacturer.csv')

df_vaccin.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df_vaccin_man.head()
# Out:
#     location        date             vaccine  total_vaccinations
# 0  Argentina  2020-12-29             Moderna                   2
# 1  Argentina  2020-12-29  Oxford/AstraZeneca                   3
# 2  Argentina  2020-12-29   Sinopharm/Beijing                   1
# 3  Argentina  2020-12-29           Sputnik V               20481
# 4  Argentina  2020-12-30             Moderna                   2

# %% [markdown]
# ## Visualisation du dataset principal "Vaccination par pays"

# %%
df_vaccin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
df_vaccin.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        4.360700e+04       4.129400e+04             3.880200e+04
# mean         4.592964e+07       1.770508e+07             1.413830e+07
# std          2.246004e+08       7.078731e+07             5.713920e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          5.264100e+05       3.494642e+05             2.439622e+05
# 50%          3.590096e+06       2.187310e+06             1.722140e+06
# 75%          1.701230e+07       9.152520e+06             7.559870e+06
# max          3.263129e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.536200e+04        8.621300e+04
# mean             2.705996e+05        1.313055e+05
# std              1.212427e+06        7.682388e+05
# min              0.000000e+00        0.000000e+00
# 25%              4.668000e+03        9.000000e+02
# ...

# %% [markdown]
# ## Nettoyage ou non des données

# %%
df_vaccin.isna().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     42905
# people_vaccinated                      45218
# people_fully_vaccinated                47710
# daily_vaccinations_raw                 51150
# daily_vaccinations                       299
# total_vaccinations_per_hundred         42905
# people_vaccinated_per_hundred          45218
# people_fully_vaccinated_per_hundred    47710
# daily_vaccinations_per_million           299
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df_vaccin.isnull().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                     42905
# people_vaccinated                      45218
# people_fully_vaccinated                47710
# daily_vaccinations_raw                 51150
# daily_vaccinations                       299
# total_vaccinations_per_hundred         42905
# people_vaccinated_per_hundred          45218
# people_fully_vaccinated_per_hundred    47710
# daily_vaccinations_per_million           299
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %% [markdown]
# Il semble que des données manquent pour certains pays.

# %%
len(df_vaccin['date'].unique())
# Out:
# 483

# %% [markdown]
# Il y a à peu près 500 dates différentes pour chaque pays, voyons lesquels manquent de données.

# %%
country = df_vaccin['country'].unique().tolist()

for c in country:
    df_temp=df_vaccin[df_vaccin['country']==c]
    if df_temp['total_vaccinations'].isna().sum() != 0:
        valeurs_na = df_temp['total_vaccinations'].isna().sum()
        print(f'En ce qui concerne le pays du {c}, il manque {valeurs_na} valeurs pour les vaccinations totales')
# Out:
# En ce qui concerne le pays du Afghanistan, il manque 348 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Albania, il manque 191 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Algeria, il manque 381 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Andorra, il manque 371 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Angola, il manque 326 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Anguilla, il manque 366 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Antigua and Barbuda, il manque 302 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Armenia, il manque 305 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Aruba, il manque 91 valeurs pour les vaccinations totales
# En ce qui concerne le pays du Australia, il manque 5 valeurs pour les vaccinations totales
# ...
