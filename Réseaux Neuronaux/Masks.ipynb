# %% [markdown]
# # Face Mask Habits and Beliefs Among Young Adults

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
from rich import print
import seaborn as sns

# %%
df_masks = pd.read_csv('MaskBeliefs.csv')

# %%
df_masks.head()
# Out:
#             Timestamp  Boarding  Age  Gender ResidentialElder InteractedElder  \
# 0  9/25/2020 15:04:43       Day   16  Female               No             Yes
# 1  9/25/2020 15:04:46  Boarding   17    Male               No              No
# 2  9/25/2020 15:04:58  Boarding   17    Male               No             Yes
# 3  9/25/2020 15:05:12       Day   17  Female               No             Yes
# 4  9/25/2020 15:05:12       Day   17  Female               No             Yes
#
#    Restaurant PreventSpread                          Reason Public
# 0         1.0           Yes  To protect yourself AND others    Yes
# 1         2.0           Yes  To protect yourself AND others    Yes
# 2         0.0           Yes  To protect yourself AND others    Yes
# 3         2.0           Yes  To protect yourself AND others    Yes
# 4         2.0           Yes  To protect yourself AND others    Yes

# %%
df_masks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Timestamp         107 non-null    object
#  1   Boarding          107 non-null    object
#  2   Age               107 non-null    int64
#  3   Gender            106 non-null    object
#  4   ResidentialElder  107 non-null    object
#  5   InteractedElder   107 non-null    object
#  6   Restaurant        105 non-null    float64
#  7   PreventSpread     107 non-null    object
#  8   Reason            107 non-null    object
#  9   Public            107 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 8.5+ KB

# %%
df_masks.describe()
# Out:
#               Age  Restaurant
# count  107.000000  105.000000
# mean    15.981308    0.752381
# std      1.243711    1.657042
# min     12.000000    0.000000
# 25%     15.000000    0.000000
# 50%     16.000000    0.000000
# 75%     17.000000    1.000000
# max     18.000000   12.000000

# %% [markdown]
# ## Nettoyage de données

# %%
df_masks.isna().sum()
# Out:
# Timestamp           0
# Boarding            0
# Age                 0
# Gender              1
# ResidentialElder    0
# InteractedElder     0
# Restaurant          2
# PreventSpread       0
# Reason              0
# Public              0
# dtype: int64

# %% [markdown]
# Le dataset est complètement propre.

# %% [markdown]
# ## Visualisations des données

# %% [markdown]
# Visualisation du boarding

# %%
df_masks['Boarding'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Visualisation de l'âge

# %%
plt.hist(df_masks['Age'], bins=25)
plt.show()

# %% [markdown]
# Visualisation du genre

# %%
df_masks['Gender'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Personnnes âgées en résidence

# %%
df_masks['ResidentialElder'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Personnes âgées en interaction

# %%
df_masks['InteractedElder'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Restaurants

# %%
plt.hist(df_masks['Restaurant'], bins=25)
plt.show()

# %% [markdown]
# Prévention diffusée

# %%
df_masks['PreventSpread'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Raison de port du masque

# %%
df_masks['Reason'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Publique

# %%
df_masks['Public'].value_counts().plot.pie()
plt.show()
