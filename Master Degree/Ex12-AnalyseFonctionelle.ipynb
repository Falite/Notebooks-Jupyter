# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# On va représenter $f_n (t) = t^n $ sur $\mathcal F \subset \mathcal C( [0,1],\mathbb R),~~\mathcal F = \{f_n,~n \geq 0\}$
# On appelle $f_n$ "f(t,n)"
# On fixe les bornes du compact "limg" = $0$ et "limd" = $1$

# %%
def f(t,n):
    return t**n 

limg=0
limd=1

xp=np.linspace(limg,limd,100)

# %%
plt.figure(figsize=(10,6))
        
for i in range(0,11):
    plt.plot(xp,f(i,xp), label=f'$f_{i}(t) = t^{i}$')
    
plt.title('Courbes $f_n(t) = t^n$')
plt.xlabel('t')
plt.ylabel('$f_n(t)$')
plt.yticks(range(0,10))
plt.xticks([i/10 for i in range(1,10)])
plt.xlim(0,1)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# On va représenter $f_n (t) = sin(nt) $ sur $\mathcal F \subset \mathcal C( [0,1],\mathbb R),~~\mathcal F = \{f_n,~n \geq 0\}$
# On appelle $f_n$ "f(t,n)"
# On fixe les bornes du compact "limg" = $0$ et "limd" = $1$

# %%
whos
# Out:
# Interactive namespace is empty.

# %%
def f(t,n):
    return np.sin(n*t)

limg=0
limd=1

xp=np.linspace(limg,limd,100)

# %%
plt.figure(figsize=(10,6))
        
for i in range(0,11):
    plt.plot(xp,f(i,xp), label=f'$f_{i}(t) = \sin({i}t)$')
    
plt.title('Courbes $f_n(t) = \sin(nt)$')
plt.xlabel('t')
plt.ylabel('$f_n(t)$')
plt.yticks(range(0,10))
plt.xticks([i/10 for i in range(1,10)])
plt.xlim(0,1)
plt.ylim(-1.2,1.2)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# f          function    <function f at 0x10a8d67a0>
# i          int         10
# limd       int         1
# limg       int         0
# np         module      <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# plt        module      <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# xp         ndarray     100: 100 elems, type `float64`, 800 bytes

# %%
del f; del i; del limd; del limg; del xp

# %%
def f(t,n):
    return np.sin(n+t)

limg=0
limd=1

xp=np.linspace(limg,limd,100)

# %%
plt.figure(figsize=(10,6))
        
for i in range(0,11):
    plt.plot(xp,f(i,xp), label=f'$f_{i}(t) = \sin({i}+t)$')
    
plt.title('Courbes $f_n(t) = \sin(n+t)$')
plt.xlabel('t')
plt.ylabel('$f_n(t)$')
plt.yticks(range(0,10))
plt.xticks([i/10 for i in range(1,10)])
plt.xlim(0,1)
plt.ylim(-1.2,1.2)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
