# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def f(x):
    return x*np.log(x)

# %%
def fsecond(x):
    return 1/x

# %%
X=np.linspace(1,20,1000)

# %%
plt.plot(X,f(X),'r')
plt.xlabel('values of x>0')
plt.ylabel('

# %%
X2=np.linspace(-20,20,1000)

# %%
plt.plot(X2,fsecond(X2),'b')
