# %% [markdown]
# <center><img src="https://polytech.univ-lyon1.fr/uas/polytech/LOGO/UDL_logo_blanc-01%20(2).png" alt="drawing" style="width:100px;"/></center>
#
# # Introduction à Python pour la Data Science
#
# ## Exercices de Data Manipulation

# %% [markdown]
# Importer la librairie Pandas(import).

# %%
import pandas as pd

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# ### Question 1
# Importer le fichier«Produits.xlsx» dans un Data.frame (read_excel) (voir http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html).

# %%
df=pd.read_excel("/Users/abdoullatifomarjee/Documents/Notebooks-Jupyter/Analyse de données/Produits.xlsx")
df.head()
# Out:
#                  Nom                  Categorie    Origine  Ville   Prix  \
# 0       Alice Mutton                    Viandes        CEE   Lyon  195.0
# 1      Aniseed Syrup                 Condiments  Exterieur  Paris   50.0
# 2   Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris   92.0
# 3  Camembert Pierrot          Produits laitiers  Exterieur  Paris  170.0
# 4   Carnarvon Tigers  Poissons et fruits de mer  Exterieur   Lyon  312.5
#
#    Stock  Valeur
# 0      0     0.0
# 1     25  1250.0
# 2     30  2760.0
# 3      0     0.0
# 4      0     0.0

# %% [markdown]
# ### Question 2
#
# Afficher les informations concernant l’ensemble de données importé (info).
#
# Combien y a-t-il d’observations et de variables dans le fichier ?

# %%
df.info()
df.describe()  #il y a 77 variables et 3 observations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nom        77 non-null     object
#  1   Categorie  77 non-null     object
#  2   Origine    77 non-null     object
#  3   Ville      77 non-null     object
#  4   Prix       77 non-null     float64
#  5   Stock      77 non-null     int64
#  6   Valeur     77 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.3+ KB
#               Prix      Stock        Valeur
# count    77.000000  77.000000     77.000000
# mean    144.331818  12.467532   1507.798701
# std     169.075557  10.931105   2585.013287
# min      12.500000   0.000000      0.000000
# 25%      66.250000   0.000000      0.000000
# 50%      97.500000  10.000000    900.000000
# 75%     166.250000  25.000000   1950.000000
# max    1317.500000  30.000000  19762.500000

# %%
df.tail()
# Out:
#                                Nom          Categorie    Origine  Ville  \
# 72  Uncle Bobs Organic Dried Pears      Produits secs  Exterieur  Paris
# 73                Valkoinen suklaa           Desserts        CEE  Paris
# 74                    Vegie-spread         Condiments  Exterieur  Paris
# 75       Wimmers gute Semmelknodel  Pates et cereales        CEE   Lyon
# 76                   Zaanse koeken           Desserts  Exterieur   Lyon
#
#       Prix  Stock  Valeur
# 72  150.00     10  1500.0
# 73   81.25     30  2437.5
# 74  219.50      5  1097.5
# 75  166.25     30  4987.5
# 76   47.50      0     0.0

# %% [markdown]
# ### Question 3
#
# Afficher les 10 premières lignes des données (head).

# %%
df.head(10)
# Out:
#                            Nom                  Categorie    Origine  Ville  \
# 0                 Alice Mutton                    Viandes        CEE   Lyon
# 1                Aniseed Syrup                 Condiments  Exterieur  Paris
# 2             Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris
# 3            Camembert Pierrot          Produits laitiers  Exterieur  Paris
# 4             Carnarvon Tigers  Poissons et fruits de mer  Exterieur   Lyon
# 5                         Chai                   Boissons        CEE   Lyon
# 6                        Chang                   Boissons  Exterieur   Lyon
# 7             Chartreuse verte                   Boissons  Exterieur   Lyon
# 8  Chef Antons Cajun Seasoning                 Condiments        CEE   Lyon
# 9        Chef Antons Gumbo Mix                 Condiments        CEE  Paris
#
#      Prix  Stock  Valeur
# 0  195.00      0     0.0
# 1   50.00     25  1250.0
# 2   92.00     30  2760.0
# 3  170.00      0     0.0
# ...

# %% [markdown]
# ### Question 4
#
# Extraire le Nom, Catégorie, Origine et Prix des produits, pour :
# - Catégorie= boissons
# - Catégorie= boissons et prix >100
# - Catégorie= boissons et origine=CEE et prix > 100
# - Catégorie= boissons ou catégorie = condiments
# - Catégorie= boissons et origine = CEE OU catégorie = condiment
# - Catégorie= viande ET origine = CEE OU catégorie = condiment ET origine = extérieur
# - prix > 70 et prix <=100
# - Lister les aliments dont le prix est compris entre 100 et 200, et qui sont des «viandes»
# - Lister les 15 produits les moins chers
# - Calculer la moyenne de prix des boissons distribuées à Lyon(pivot_table)
# - Quels sont les 5 produits les moins chers vendus à Lyon?

# %%
df.loc[df['Categorie'] == 'Boissons', ['Nom','Categorie','Origine','Prix']]
# Out:
#                           Nom Categorie    Origine     Prix
# 5                        Chai  Boissons        CEE    90.00
# 6                       Chang  Boissons  Exterieur    95.00
# 7            Chartreuse verte  Boissons  Exterieur    90.00
# 11              Côte de Blaye  Boissons        CEE  1317.50
# 21         Guarana Fantastica  Boissons  Exterieur    22.50
# 28                Ipoh Coffee  Boissons  Exterieur   230.00
# 31               Lakkalikoori  Boissons        CEE    90.00
# 32  Laughing Lumberjack Lager  Boissons        CEE    70.00
# 45              Outback Lager  Boissons  Exterieur    75.00
# 53       Rhonbrau Klosterbier  Boissons        CEE    38.75
# 57              Sasquatch Ale  Boissons        CEE    70.00
# 65             Steeleye Stout  Boissons  Exterieur    90.00

# %%
df.loc[(df['Categorie']=='Boissons') & (df['Prix']>100), ['Nom','Categorie','Origine','Prix']]
# Out:
#               Nom Categorie    Origine    Prix
# 11  Côte de Blaye  Boissons        CEE  1317.5
# 28    Ipoh Coffee  Boissons  Exterieur   230.0

# %%
df.loc[(df['Categorie']=='Boissons') & (df['Prix']>100) & (df['Origine']=='CEE'),
       ['Nom','Categorie','Origine','Prix']]
# Out:
#               Nom Categorie Origine    Prix
# 11  Côte de Blaye  Boissons     CEE  1317.5

# %%
df.loc[(df['Categorie']=='Boissons') | (df['Categorie']=='Condiments') ,
       ['Nom','Categorie','Origine','Prix']]
# Out:
#                                  Nom   Categorie    Origine     Prix
# 1                      Aniseed Syrup  Condiments  Exterieur    50.00
# 5                               Chai    Boissons        CEE    90.00
# 6                              Chang    Boissons  Exterieur    95.00
# 7                   Chartreuse verte    Boissons  Exterieur    90.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE   106.75
# 11                     Côte de Blaye    Boissons        CEE  1317.50
# 16                      Genen Shouyu  Condiments        CEE    77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   125.00
# 21                Guarana Fantastica    Boissons  Exterieur    22.50
# 23                      Gula Malacca  Condiments        CEE    97.25
# 28                       Ipoh Coffee    Boissons  Exterieur   230.00
# 31                      Lakkalikoori    Boissons        CEE    90.00
# ...

# %%
df.loc[((df['Categorie']=='Boissons')&(df['Origine']=='CEE')) | (df['Categorie']=='Condiments') ,
       ['Nom','Categorie','Origine','Prix']]
# Out:
#                                  Nom   Categorie    Origine     Prix
# 1                      Aniseed Syrup  Condiments  Exterieur    50.00
# 5                               Chai    Boissons        CEE    90.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE   106.75
# 11                     Côte de Blaye    Boissons        CEE  1317.50
# 16                      Genen Shouyu  Condiments        CEE    77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   125.00
# 23                      Gula Malacca  Condiments        CEE    97.25
# 31                      Lakkalikoori    Boissons        CEE    90.00
# 32         Laughing Lumberjack Lager    Boissons        CEE    70.00
# 34  Louisiana Fiery Hot Pepper Sauce  Condiments        CEE   105.25
# 35         Louisiana Hot Spiced Okra  Condiments        CEE    85.00
# 42        Northwoods Cranberry Sauce  Condiments  Exterieur   200.00
# ...

# %% [markdown]
# Catégorie= viande ET origine = CEE OU catégorie = condiment ET origine = extérieur

# %%
df.loc[(df['Categorie']=='Viande') & (df['Origine']=='CEE') | 
       ( df['Categorie']=='Condiments') & (df['Origine']=='Exterieur'),
       ['Nom','Categorie','Origine','Prix']]
# Out:
#                                 Nom   Categorie    Origine   Prix
# 1                     Aniseed Syrup  Condiments  Exterieur   50.0
# 19      Grandmas Boysenberry Spread  Condiments  Exterieur  125.0
# 42       Northwoods Cranberry Sauce  Condiments  Exterieur  200.0
# 44  Original Frankfurter grüne Soße  Condiments  Exterieur   65.0
# 63                    Sirop derable  Condiments  Exterieur  142.5
# 74                     Vegie-spread  Condiments  Exterieur  219.5

# %% [markdown]
# - Catégorie= viande ET origine = CEE OU catégorie = condiment ET origine = extérieur

# %%
df.loc[(df['Categorie']=='Viande')&(df['Origine']=='CEE') | (df['Categorie']=='Condiments') & (df['Origine']=='Exterieur'),
       ['Nom','Categorie','Origine','Prix']]
# Out:
#                                 Nom   Categorie    Origine   Prix
# 1                     Aniseed Syrup  Condiments  Exterieur   50.0
# 19      Grandmas Boysenberry Spread  Condiments  Exterieur  125.0
# 42       Northwoods Cranberry Sauce  Condiments  Exterieur  200.0
# 44  Original Frankfurter grüne Soße  Condiments  Exterieur   65.0
# 63                    Sirop derable  Condiments  Exterieur  142.5
# 74                     Vegie-spread  Condiments  Exterieur  219.5

# %%
df.loc[(df['Prix']>70)&(df['Prix']<=100) ,
       ['Nom','Categorie','Origine','Prix']]
# Out:
#                           Nom                  Categorie    Origine    Prix
# 2            Boston Crab Meat  Poissons et fruits de mer  Exterieur   92.00
# 5                        Chai                   Boissons        CEE   90.00
# 6                       Chang                   Boissons  Exterieur   95.00
# 7            Chartreuse verte                   Boissons  Exterieur   90.00
# 16               Genen Shouyu                 Condiments        CEE   77.50
# 23               Gula Malacca                 Condiments        CEE   97.25
# 27                Inlagd Sill  Poissons et fruits de mer  Exterieur   95.00
# 31               Lakkalikoori                   Boissons        CEE   90.00
# 35  Louisiana Hot Spiced Okra                 Condiments        CEE   85.00
# 38                   Maxilaku                   Desserts        CEE  100.00
# 45              Outback Lager                   Boissons  Exterieur   75.00
# ...

# %%
df.loc[(df['Prix']>100)&(df['Prix']<=200)&(df['Categorie']=='Viandes'),
       ['Nom','Categorie','Origine','Prix']]
# Out:
#               Nom Categorie Origine   Prix
# 0    Alice Mutton   Viandes     CEE  195.0
# 46   Pate chinois   Viandes     CEE  120.0
# 48  Perth Pasties   Viandes     CEE  164.0

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# df         DataFrame                             <...>\n\n[77 rows x 7 columns]
# np         module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# pd         module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>

# %%
import numpy as np
df_mean_ville=pd.pivot_table(df,index=["Categorie","Ville"],values=["Prix"],aggfunc=np.mean)
df_mean_ville.head()
# Out:
#                         Prix
# Categorie  Ville
# Boissons   Lyon    76.944444
#            Paris  528.750000
# Condiments Lyon   125.000000
#            Paris  110.468750
# Desserts   Lyon   119.750000

# %%
df_lyon=df.loc[df['Ville']=='Lyon',
               ['Nom','Categorie','Origine','Ville','Prix','Stock','Valeur']]
df_lyon.sort_values(by='Prix')
# Out:
#                                 Nom                  Categorie    Origine  \
# 15                          Geitost          Produits laitiers        CEE
# 21               Guarana Fantastica                   Boissons  Exterieur
# 30                            Konbu  Poissons et fruits de mer        CEE
# 67       Teatime Chocolate Biscuits                   Desserts  Exterieur
# 76                    Zaanse koeken                   Desserts  Exterieur
# 29   Jacks New England Clam Chowder  Poissons et fruits de mer  Exterieur
# 33                    Longlife Tofu              Produits secs  Exterieur
# 62               Sir Rodneys Scones                   Desserts        CEE
# 64                        Spegesild  Poissons et fruits de mer  Exterieur
# 18                Gorgonzola Telino          Produits laitiers        CEE
# 44  Original Frankfurter grüne Soße                 Condiments  Exterieur
# 57                    Sasquatch Ale                   Boissons        CEE
# ...

# %% [markdown]
# ## Exercice 2
#
# Importer le dataset euro12.

# %%
euro12=pd.read_csv('/Users/abdoullatifomarjee/Documents/Notebooks-Jupyter/Analyse de données/euro12.csv')
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# ### Question 1
#
# Combien de participants à cette compétition ?

# %%
euro12.shape
#il y a 16 participants
# Out:
# (16, 35)

# %% [markdown]
# ### Question 2
#
# Garder uniquement les colonnes Team, Yellow Cards and Red Cards que vous assignerez à un nouveau dataframe nommé discipline.

# %%
euro12.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
discipline=euro12[['Team','Yellow Cards','Red Cards']]
discipline.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
discipline.shape
# Out:
# (16, 3)

# %% [markdown]
# ### Question 3
#
# Triez les valeurs par nombre de cartons rouges puis de cartons jaunes.

# %%
discipline=discipline.sort_values(by='Red Cards',ascending=True)
discipline.tail()
# Out:
#                    Team  Yellow Cards  Red Cards
# 14               Sweden             7          0
# 15              Ukraine             5          0
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1

# %%
discipline=discipline.sort_values(by='Yellow Cards',ascending=True)
discipline.tail()
# Out:
#         Team  Yellow Cards  Red Cards
# 0    Croatia             9          0
# 6     Greece             9          1
# 13     Spain            11          0
# 10  Portugal            12          0
# 7      Italy            16          0

# %% [markdown]
# ### Question 4
#
# Combien d'équipes ont marqué plus de 6 buts ?

# %%
len(euro12.loc[(euro12['Goals']>6),'Team']) #deux
# Out:
# 2

# %% [markdown]
# ## Exercice 3
#
# Importer le dataset alcohol.

# %%
alcool=pd.read_csv('/Users/abdoullatifomarjee/Documents/Notebooks-Jupyter/Analyse de données/alcohol.csv')
alcool.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %% [markdown]
# ### Question 1
#
# Quel continent boit le plus de bières en moyenne ?

# %%
alcool.loc[alcool['beer_servings'].idxmax(),'country']
# Out:
# 'Namibia'

# %% [markdown]
# ### Question 2
#
# Quelle est la consommation moyenne par continent de chaque type de boisson ?

# %%
alcool['continent'].unique()
# Out:
# array(['AS', 'EU', 'AF', nan, 'SA', 'OC'], dtype=object)

# %%
listnoms=alcool.columns.tolist()
listnoms.remove('country')
listnoms.remove('total_litres_of_pure_alcohol')
listnoms.remove('continent')
listnoms
# Out:
# ['beer_servings', 'spirit_servings', 'wine_servings']

# %%
for index in listnoms :
    print(alcool.groupby('continent')[index].mean())
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64
# continent
# AF     16.339623
# AS     60.840909
# EU    132.555556
# OC     58.437500
# SA    114.750000
# Name: spirit_servings, dtype: float64
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64

# %% [markdown]
# ### Question 3
#
# Afficher la médiane, le minimum et le maximum de la colonne "spirit consumption".

# %%
alcool.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
alcool['spirit_servings'].describe()
# Out:
# count    193.000000
# mean      80.994819
# std       88.284312
# min        0.000000
# 25%        4.000000
# 50%       56.000000
# 75%      128.000000
# max      438.000000
# Name: spirit_servings, dtype: float64

# %% [markdown]
# ## Exercice 4
#
# Importer le dataset us_crime_rates.

# %% [markdown]
# La décennie 60 comprend les années entre 1960 et 1969.
# Le dataset us_crime_rates donne les sommes cumulatives par années de différents indicateurs.

# %%
uscrime=pd.read_csv('/Users/abdoullatifomarjee/Documents/Notebooks-Jupyter/Analyse de données/us_crime_rates.csv')
uscrime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
uscrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
uscrime.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# ...

# %% [markdown]
# ### Question 1
#
# Créer le dataframe qui donne chaque indicateur pour chaque décennie. Résultat ci-dessous.

# %%
whos
# Out:
# Variable        Type         Data/Info
# --------------------------------------
# Image           type         <class 'IPython.core.display.Image'>
# df              DataFrame                             <...>\n\n[77 rows x 7 columns]
# df_lyon         DataFrame                             <...>  47.50      0     0.00
# df_mean_ville   DataFrame                             <...>        Paris  100.625000
# np              module       <module 'numpy' from '/Us<...>kages/numpy/__init__.py'>
# pd              module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# uscrime         DataFrame        Year  Population     <...> 5858496         689527

# %%
# Création d'une nouvelle colonne 'Decade' en utilisant la division entière par 10 sur la colonne 'Year'
uscrime['Decade'] = uscrime['Year'] // 10 * 10

# %%
uscrime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft  Decade
# 0   107840              154320    912100        1855400         328200    1960
# 1   106670              156760    949600        1913000         336000    1960
# 2   110860              164570    994300        2089600         366800    1960
# 3   116470              174210   1086400        2297800         408300    1960
# 4   130390              203050   1213200        2514400         472800    1960

# %%
uscrimedec = uscrime.groupby('Decade').sum()
uscrimedec.head()
# Out:
#          Year  Population      Total   Violent   Property  Murder  \
# Decade
# 1960    19645  1915053175   49295900   4134930   45160900  106180
# 1970    19745  2121193298  100991600   9607930   91383800  192230
# 1980    19845  2371370069  131123369  14074328  117048900  206439
# 1990    19945  2612825258  136582146  17527048  119053499  211664
# 2000    20045  2947969117  115012044  13968056  100944369  163068
#
#         Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Decade
# 1960           236720  1633510             2158520  13321100       26547700
# 1970           554570  4159020             4702120  28486000       53157800
# 1980           865639  5383109             7619130  33073494       72040253
# 1990           998827  5748930            10568963  26750015       77679366
# 2000           922499  4230366             8652124  21565176       67970291
#
#         Vehicle_Theft
# Decade
# 1960          5292100
# 1970          9739900
# ...

# %%
uscrimedec = uscrimedec.drop('Year', axis=1)

# %%
uscrimedec
# Out:
#         Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Decade
# 1960    1915053175   49295900   4134930   45160900  106180         236720
# 1970    2121193298  100991600   9607930   91383800  192230         554570
# 1980    2371370069  131123369  14074328  117048900  206439         865639
# 1990    2612825258  136582146  17527048  119053499  211664         998827
# 2000    2947969117  115012044  13968056  100944369  163068         922499
# 2010    1570146307   50167967   6072017   44095950   72867         421059
#
#         Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Decade
# 1960    1633510             2158520  13321100       26547700        5292100
# 1970    4159020             4702120  28486000       53157800        9739900
# 1980    5383109             7619130  33073494       72040253       11935411
# 1990    5748930            10568963  26750015       77679366       14624418
# ...

# %% [markdown]
# ### Question 2
#
# Quelle était la plus dangereuse décennie aux USA ?

# %%
for i in uscrimedec.columns.tolist():
    uscrimedec[i].idxmax()
# Out:
# ['Population',
#  'Total',
#  'Violent',
#  'Property',
#  'Murder',
#  'Forcible_Rape',
#  'Robbery',
#  'Aggravated_assault',
#  'Burglary',
#  'Larceny_Theft',
#  'Vehicle_Theft']

# %% [markdown]
# ## Enseignant
# Patrice Mazel - patrice.mazel@protonmail.com - 3A MAM 2023/2024
